# %%
import pandas as pd

# %%
inpi_brevets = pd.read_csv("../datas/fr-esr-brevets-france-inpi-oeb.csv", sep=';')
print(inpi_brevets.head)
# Out:
# <bound method NDFrame.head of        num_depot origine  annees_publication  annees_delivrance part  \
# 0        1161944  France                2013             2013.0  Non
# 1        0400729  France                2005             2006.0  Non
# 2        0512601  France                2007                NaN  Non
# 3        1150006  France                2012             2014.0  Non
# 4        1101373  France                2012             2014.0  Non
# ...          ...     ...                 ...                ...  ...
# 222622   0402041  France                2005                NaN  Non
# 222623   0402056  France                2005             2007.0  Non
# 222624   1058214  France                2012             2013.0  Non
# 222625   1158228  France                2013             2014.0  Non
# 222626   0402205  France                2005             2006.0  Non
#
#                              type_d_tablissement  num_siren    id_dep  \
# ...

# %%
# ":" to select all rows columns
# "-4" excepted the four lasts

inpi_brevets = inpi_brevets.iloc[:, :-4]
print(inpi_brevets.head)
# Out:
# <bound method NDFrame.head of        num_depot origine  annees_publication  annees_delivrance part  \
# 0        1161944  France                2013             2013.0  Non
# 1        0400729  France                2005             2006.0  Non
# 2        0512601  France                2007                NaN  Non
# 3        1150006  France                2012             2014.0  Non
# 4        1101373  France                2012             2014.0  Non
# ...          ...     ...                 ...                ...  ...
# 222622   0402041  France                2005                NaN  Non
# 222623   0402056  France                2005             2007.0  Non
# 222624   1058214  France                2012             2013.0  Non
# 222625   1158228  France                2013             2014.0  Non
# 222626   0402205  France                2005             2006.0  Non
#
#                              type_d_tablissement  num_siren    id_dep  \
# ...

# %%
inpi_brevets.to_csv('../datas/datas-brevets-france-inpi-oeb_without_last_4_cols.csv', index=False)
